# %%
#4.6 Task
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import large combined df
df_ords_prods_combo= pd.read_pickle(r'/Users/sarahboller/Desktop/CF 4 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
# Check shape to make sure it matches
df_ords_prods_combo.shape
# Out:
# (32434489, 12)

# %%
df_prods= pd.read_csv(r'/Users/sarahboller/Desktop/CF 4 Instacart Basket Analysis/02 Data/Prepared Data/products_checked_1.csv', index_col = False)

# %%
# Import Product df
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Check shape of prods df
df_prods.shape
# Out:
# (49672, 6)

# %%
df_ords_prods_combo.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    time_of_order_hr  days_since_prior_order  returning_customer  product_id  \
# 0                 8                     NaN               False         196
# 1                 8                     NaN               False       14084
# 2                 8                     NaN               False       12427
# 3                 8                     NaN               False       26088
# 4                 8                     NaN               False       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
# Dropping the merge column from the first merge. 
df_op_combo = df_ords_prods_combo.drop(columns =['_merge'])

# %%
df_op_combo.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    time_of_order_hr  days_since_prior_order  returning_customer  product_id  \
# 0                 8                     NaN               False         196
# 1                 8                     NaN               False       14084
# 2                 8                     NaN               False       12427
# 3                 8                     NaN               False       26088
# 4                 8                     NaN               False       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# ...

# %%
# Merging df_prods with large ords df
df_all_merged = df_op_combo.merge(df_prods, on = 'product_id', indicator = True)

# %%
# Checking shape and other attributes 
df_all_merged.shape
# Out:
# (32404859, 17)

# %%
df_all_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_all_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    time_of_order_hr  days_since_prior_order  returning_customer  product_id  \
# 0                 8                     NaN               False         196
# 1                 7                    15.0                True         196
# 2                12                    21.0                True         196
# 3                 7                    29.0                True         196
# 4                15                    28.0                True         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
path = r'/Users/sarahboller/Desktop/CF 4 Instacart Basket Analysis'

# %%
# Exporting 
df_all_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
